# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Colab Notebooks/alpaco/Team_1. CODEnter [ Save Form : Name_FileName_Date ]/2. SUB _ MUSINSA/'

# %%
df_1 = pd.read_csv(path + '4. csv/' + 'comment_data_mouth1.csv', index_col=0)
df_2 = pd.read_csv(path + '4. csv/' + 'comment_data_mouth2.csv', index_col=0)
df_3 = pd.read_csv(path + '4. csv/' + 'comment_data_mouth3.csv', index_col=0)
df_4 = pd.read_csv(path + '4. csv/' + 'comment_data_mouth4.csv', index_col=0)
df_5 = pd.read_csv(path + '4. csv/' + 'comment_data_mouth5_6.csv', index_col=0)
df_6 = pd.read_csv(path + '4. csv/' + 'comment_data_2021.csv', index_col=0)

# %%
df_5.drop_duplicates(inplace=True)
df_5
# Out:
#        month  page                                            comment  star
# 0          5     1  셔츠자켓이라는 옷은 처음 구매해보는데요 굉장히 편리하고 좋습니다 그리고 옷의 컬러가...     5
# 1          5     1              오바핏일 줄 알고 에스로 샀는데 엠 갈걸 그랬네요ㅜㅜ 그냥 딱맞아여     5
# 2          5     1  런쥐니가 입어서 샀는데 배송도 빨랐고 따듯하구 귀여워요&hellip;좀 오버핏을 원...     5
# 3          5     1                   제꺼사고 엄마가 탐내길래 하나 사드렸습니다 귀엽고 이쁘네요     5
# 4          5     1                  모자 깊이도 깊고 챙고 길어서 동네 잠깐 나갈때 쓰기 좋아여     5
# ...      ...   ...                                                ...   ...
# 40028      6  1001             사진에서 본대로 진짜 너무 이쁘고 바지는 아무거나 입어도 잘 어울려요     5
# 40029      6  1001  넘 예쁘고 맘에 들어요 가성비도 짱이에요. 추천합니다. 다음에도 여기서 가방 살 거...     5
# 40030      6  1001        굿이에요 정말 딱 이코디에는 대박 잇템입니다 다음엔 다른코디에 도전해볼께요^^     5
# 40031      6  1001                   여자친구가입었는데 색 진짜이쁨여  브랜드 색감 잘뽑네 진짜     5
# 40032      6  1001       아들 주려산건데 내가 입어야할듯요. 넘 맘에들고 이쁘네요. 재질도 톡톡하니 굿굿     5
#
# [38704 rows x 4 columns]

# %%
# main_data_df = pd.concat([df_1, df_2, df_3, df_4], axis = 0)
main_data_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6], axis = 0)

# %%
main_data_df
# Out:
#         month  page                                            comment  star
# 0           1     1  휘뚜루마뚜루 입고 다니기 좋습니다 로얄라이프제품들은 다 성공하는 듯!따숩고 예쁘기까...     5
# 1           1     1                어깨 깡패됩니다 기장감이나 털 재질 전체적으로 전부 맘에 들어요     5
# 2           1     1                   바지 짱 편합니다ㅎㅎ 색깔도 너무 마음에 들고 핏도 좋네요     5
# 3           1     1  입기 편하고 후드 탈부착 돼서 여러 무드 연출하기도 쉽고 좋은데 가죽냄새랑 마감이 ...     4
# 4           1     1            유니폼 브릿지 발마칸 코트! 세일.기간중 저렴하게 겟겟! 최고 말모말모     5
# ...       ...   ...                                                ...   ...
# 240209     12  1001                      가방이 아주 포인트 그 자체라서 빤딱하고 너무 좋아요     5
# 240210     12  1001                        보들보둘하고 사이즈도 괜찮고 색도 이쁘게 잘나왔음     5
# 240211     12  1001                    생각보다 클 줄 알고 샀다가 조금 작았네요 그래도 좋아요     4
# 240212     12  1001  생각보다 색상이 밝고 사이즈는 조금 작게 나온거 같아요.길이는 좀 길지만 수선안하고...     5
# 240213     12  1001                 매번 갖고 싶었던 ㅈ품 이였는데 이번에 얻어ㅛ네요ㅎㅎ감사합ㄴ닽     5
#
# [882600 rows x 4 columns]

# %%
main_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882600 entries, 0 to 240213
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   month    882600 non-null  int64
#  1   page     882600 non-null  int64
#  2   comment  882600 non-null  object
#  3   star     882600 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 33.7+ MB

# %%
main_data_df.drop_duplicates(inplace=True)

# %%
main_data_df.reset_index(drop=True, inplace=True)
main_data_df
# Out:
#         month  page                                            comment  star
# 0           1     1  휘뚜루마뚜루 입고 다니기 좋습니다 로얄라이프제품들은 다 성공하는 듯!따숩고 예쁘기까...     5
# 1           1     1                어깨 깡패됩니다 기장감이나 털 재질 전체적으로 전부 맘에 들어요     5
# 2           1     1                   바지 짱 편합니다ㅎㅎ 색깔도 너무 마음에 들고 핏도 좋네요     5
# 3           1     1  입기 편하고 후드 탈부착 돼서 여러 무드 연출하기도 쉽고 좋은데 가죽냄새랑 마감이 ...     4
# 4           1     1            유니폼 브릿지 발마칸 코트! 세일.기간중 저렴하게 겟겟! 최고 말모말모     5
# ...       ...   ...                                                ...   ...
# 882595     12  1001                      가방이 아주 포인트 그 자체라서 빤딱하고 너무 좋아요     5
# 882596     12  1001                        보들보둘하고 사이즈도 괜찮고 색도 이쁘게 잘나왔음     5
# 882597     12  1001                    생각보다 클 줄 알고 샀다가 조금 작았네요 그래도 좋아요     4
# 882598     12  1001  생각보다 색상이 밝고 사이즈는 조금 작게 나온거 같아요.길이는 좀 길지만 수선안하고...     5
# 882599     12  1001                 매번 갖고 싶었던 ㅈ품 이였는데 이번에 얻어ㅛ네요ㅎㅎ감사합ㄴ닽     5
#
# [882600 rows x 4 columns]

# %%
path = '/content/drive/MyDrive/Colab Notebooks/alpaco/Team_1. CODEnter [ Save Form : Name_FileName_Date ]/2. SUB _ MUSINSA/4. csv/'
main_data_df.to_csv(path + 'comment_data_all.csv')
