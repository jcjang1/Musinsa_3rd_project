# %% [markdown]
# 감성분석을 하기위해 Label은 0부터 시작해야함
#
# 그러나 우리 데이터셋의 Label은 1 - 5
#
# 모든 Label -1 을 해줌으로써 Label 0 - 4 로 만들어줌

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DF = pd.read_csv('/content/test_data(2000)_0623.csv', index_col=0)
df1 = DF.reset_index().drop('index', axis=1)
df1 # star = label
    # label : 1- 5
# Out:
#                                                 comment  star
# 0     사이즈표 바꿔라 270인데 m시키고 색소침착에 딱지까지 생김 250~275 퉁치는게...     1
# 1     음 가격에 비해서 좀 많이 별로네요... 일단 목부분이 처음 왔을때부터 저렇게 쭈글...     1
# 2     주머니에 빵꾸뚫려있는데 교환환불 방법이있나요 사놓고 검수를 했어야한건지 무신사를믿고...     1
# 3            가방이 벌써 뜯어졌어요ㅠㅜ 얼마 매지도 않았는데....가방이 너무 약해요ㅠㅠ     1
# 4                      생각보다는 그저 그런 후드티였어요 그냥 일반 보세느낌이에요     1
# ...                                                 ...   ...
# 1995  내복입고 입으면 타이트해서 벗고 입어야 할거 같아요 허리밴딩땜에 편하고 좋네요 리얼...     5
# 1996               아이보리 치노팬츠 하나 필요해서 샀습니다. 싸게 잘 산 것 같아용     5
# 1997     사이즈 오버핏으로 넉넉하구 따뜻해서 너무 좋아요 생지랑 니트랑 같이 입으니 귀엽네요     5
# 1998  진짜 너무 이뻐요ㅠㅠ하얗고 딱 제가 원하는 색상이예요 신발이 단단하다고 해야할까요 ...     5
# 1999    너무 예쁘네요. 보풀이 잘 일어날 것 같은 느낌인데 관리 잘 해서 오래 입고 싶습니다     5
#
# [2000 rows x 2 columns]

# %%
## Magic!
df1['star'] -= 1 # 각 라벨값을 -1씩 해줌

# %%
df1 # label : 0 - 4
# Out:
#                                                 comment  star
# 0     사이즈표 바꿔라 270인데 m시키고 색소침착에 딱지까지 생김 250~275 퉁치는게...     0
# 1     음 가격에 비해서 좀 많이 별로네요... 일단 목부분이 처음 왔을때부터 저렇게 쭈글...     0
# 2     주머니에 빵꾸뚫려있는데 교환환불 방법이있나요 사놓고 검수를 했어야한건지 무신사를믿고...     0
# 3            가방이 벌써 뜯어졌어요ㅠㅜ 얼마 매지도 않았는데....가방이 너무 약해요ㅠㅠ     0
# 4                      생각보다는 그저 그런 후드티였어요 그냥 일반 보세느낌이에요     0
# ...                                                 ...   ...
# 1995  내복입고 입으면 타이트해서 벗고 입어야 할거 같아요 허리밴딩땜에 편하고 좋네요 리얼...     4
# 1996               아이보리 치노팬츠 하나 필요해서 샀습니다. 싸게 잘 산 것 같아용     4
# 1997     사이즈 오버핏으로 넉넉하구 따뜻해서 너무 좋아요 생지랑 니트랑 같이 입으니 귀엽네요     4
# 1998  진짜 너무 이뻐요ㅠㅠ하얗고 딱 제가 원하는 색상이예요 신발이 단단하다고 해야할까요 ...     4
# 1999    너무 예쁘네요. 보풀이 잘 일어날 것 같은 느낌인데 관리 잘 해서 오래 입고 싶습니다     4
#
# [2000 rows x 2 columns]

# %% [markdown]
# ##1

# %%
one = pd.DataFrame(df1[df1['star'] ==  1])
one
# Out:
#                                                comment  star
# 0    사이즈표 바꿔라 270인데 m시키고 색소침착에 딱지까지 생김 250~275 퉁치는게...     1
# 1    음 가격에 비해서 좀 많이 별로네요... 일단 목부분이 처음 왔을때부터 저렇게 쭈글...     1
# 2    주머니에 빵꾸뚫려있는데 교환환불 방법이있나요 사놓고 검수를 했어야한건지 무신사를믿고...     1
# 3           가방이 벌써 뜯어졌어요ㅠㅜ 얼마 매지도 않았는데....가방이 너무 약해요ㅠㅠ     1
# 4                     생각보다는 그저 그런 후드티였어요 그냥 일반 보세느낌이에요     1
# ..                                                 ...   ...
# 395  어디에나 잘 어울리고 편하게 입을 수 있지만 먼지가 잘 달라붙어요. 혼용률 기재가 ...     1
# 396  사용한지 일주일도 안됬는데 찍찍이를 너무 많이 쌔게 달아놓아서 벌써 다 뜯어졌습니다...     1
# 397  정말 최악 중에 최악입니다. 9월22일에 M사이즈를 주문했는데 9월28일에 L사이즈...     1
# 398  제품 좋아요. 다만 혼용률 오기재 부분에 대한 브랜드의 대처가 제가 겪은 일도 아니...     1
# 399       아ㅡㅡ 환불안해줘요?? 사자말자 주머니가 찢어져있다고요ㅡㅡ 아 빨리보고 글남겨요     1
#
# [400 rows x 2 columns]

# %%
one['star'] = 0

# %%
one
# Out:
#                                                comment  star
# 0    사이즈표 바꿔라 270인데 m시키고 색소침착에 딱지까지 생김 250~275 퉁치는게...     0
# 1    음 가격에 비해서 좀 많이 별로네요... 일단 목부분이 처음 왔을때부터 저렇게 쭈글...     0
# 2    주머니에 빵꾸뚫려있는데 교환환불 방법이있나요 사놓고 검수를 했어야한건지 무신사를믿고...     0
# 3           가방이 벌써 뜯어졌어요ㅠㅜ 얼마 매지도 않았는데....가방이 너무 약해요ㅠㅠ     0
# 4                     생각보다는 그저 그런 후드티였어요 그냥 일반 보세느낌이에요     0
# ..                                                 ...   ...
# 395  어디에나 잘 어울리고 편하게 입을 수 있지만 먼지가 잘 달라붙어요. 혼용률 기재가 ...     0
# 396  사용한지 일주일도 안됬는데 찍찍이를 너무 많이 쌔게 달아놓아서 벌써 다 뜯어졌습니다...     0
# 397  정말 최악 중에 최악입니다. 9월22일에 M사이즈를 주문했는데 9월28일에 L사이즈...     0
# 398  제품 좋아요. 다만 혼용률 오기재 부분에 대한 브랜드의 대처가 제가 겪은 일도 아니...     0
# 399       아ㅡㅡ 환불안해줘요?? 사자말자 주머니가 찢어져있다고요ㅡㅡ 아 빨리보고 글남겨요     0
#
# [400 rows x 2 columns]

# %% [markdown]
# ##2

# %%
two = pd.DataFrame(df1[df1['star'] ==  2])
two
# Out:
#                                                comment  star
# 400              질이 넘 스ㄹㅔ기~! 원가에 샀으면 진짜 후회할뻔 했어요 ㅎㅎ 구림     2
# 401           착용감은 괜찮은데 전체적으로 색이 침침하여 할아버지 옷 느낌이 좀 나네요     2
# 402  부착하기 힘들어서 1장 실패했어요 두번째에는 성공했는데 se40mm에는 안맞아요 몇...     2
# 403                    사이즈 선택 잘해야할듯 너무 커서 앞부분이 많이 울어요ㅠ     2
# 404                        신발 발등 부분이 구겨져서 왔는데 그냥 신으려구요     2
# ..                                                 ...   ...
# 795  걍 가격대에 맞는 컬리티네요 시보리부분 보푸라기 너무 심하구요 군데군데 실밥하고 바...     2
# 796                    엄지랑 검지 발가락쪽이 다 까져서 걷기가 넘 힘드러요ㅜㅜ     2
# 797  카라가 넘 안예뻐요..ㅠㅠ 어좁이분들은 진짜 피하셔야되는 카라넓이고 그리고 카라가 ...     2
# 798  으악.. 망했다.. 일단 허벅지가 딱 달라붙어서 원했던 일자핏이 안나와요ㅠ 화이트컬...     2
# 799       체격있는 사람들 더 극대화로 만들어주는 아이 어깨넓어보이고 싶으시면 이거 사세요     2
#
# [400 rows x 2 columns]

# %%
two['star'] = 1

# %%
two
# Out:
#                                                comment  star
# 400              질이 넘 스ㄹㅔ기~! 원가에 샀으면 진짜 후회할뻔 했어요 ㅎㅎ 구림     1
# 401           착용감은 괜찮은데 전체적으로 색이 침침하여 할아버지 옷 느낌이 좀 나네요     1
# 402  부착하기 힘들어서 1장 실패했어요 두번째에는 성공했는데 se40mm에는 안맞아요 몇...     1
# 403                    사이즈 선택 잘해야할듯 너무 커서 앞부분이 많이 울어요ㅠ     1
# 404                        신발 발등 부분이 구겨져서 왔는데 그냥 신으려구요     1
# ..                                                 ...   ...
# 795  걍 가격대에 맞는 컬리티네요 시보리부분 보푸라기 너무 심하구요 군데군데 실밥하고 바...     1
# 796                    엄지랑 검지 발가락쪽이 다 까져서 걷기가 넘 힘드러요ㅜㅜ     1
# 797  카라가 넘 안예뻐요..ㅠㅠ 어좁이분들은 진짜 피하셔야되는 카라넓이고 그리고 카라가 ...     1
# 798  으악.. 망했다.. 일단 허벅지가 딱 달라붙어서 원했던 일자핏이 안나와요ㅠ 화이트컬...     1
# 799       체격있는 사람들 더 극대화로 만들어주는 아이 어깨넓어보이고 싶으시면 이거 사세요     1
#
# [400 rows x 2 columns]

# %% [markdown]
# ##3

# %%
three = pd.DataFrame(df1[df1['star'] ==  3])
three
# Out:
#                                                 comment  star
# 800   전 쿨톤인데 색깔 선택을 잘못했네요. 너무 안어울림. 살이 갑자기 쪄서 사이즈도 안...     3
# 801                다 좋은데 지퍼가 아쉽네요 몇번 만진더니 그냥 안잠기고 빡빡하네요     3
# 802           귀여워요 근데 다른거보다 얇아서 잘 찢어지고 접착력이 안좋아서 떨어져요..     3
# 803                              감사합니다잘쓰고있어요감사합니다잘쓰고있어요     3
# 804                        안녕하세요 재질 좋아요 사이즈도 딱이에요 감사합니다     3
# ...                                                 ...   ...
# 1195  음 라일론 매쉬 소재라고 해야 하나? 시원한 느낌입니다 봄에 좋을것 같고 여름에 더...     3
# 1196  솔직히 그냥 그래여 뭐 레이어드 한다고 속에 입을거라지만 그냥 단독으로 입는다면 딱...     3
# 1197  맨투맨같은 경우는 가성비가 좋다고 생각하는데 후리스는 좀 부직포로 만든 느낌이네요 ...     3
# 1198                         이뻐요 기본템으로 딱이에요 추천 봄코디도 좋아요     3
# 1199               순전히 로고가 다 합니다… 너무 불편해서 오래는 못 신겠어요 ㅠㅠ     3
#
# [400 rows x 2 columns]

# %%
three['star'] = 2

# %%
three
# Out:
#                                                 comment  star
# 800   전 쿨톤인데 색깔 선택을 잘못했네요. 너무 안어울림. 살이 갑자기 쪄서 사이즈도 안...     2
# 801                다 좋은데 지퍼가 아쉽네요 몇번 만진더니 그냥 안잠기고 빡빡하네요     2
# 802           귀여워요 근데 다른거보다 얇아서 잘 찢어지고 접착력이 안좋아서 떨어져요..     2
# 803                              감사합니다잘쓰고있어요감사합니다잘쓰고있어요     2
# 804                        안녕하세요 재질 좋아요 사이즈도 딱이에요 감사합니다     2
# ...                                                 ...   ...
# 1195  음 라일론 매쉬 소재라고 해야 하나? 시원한 느낌입니다 봄에 좋을것 같고 여름에 더...     2
# 1196  솔직히 그냥 그래여 뭐 레이어드 한다고 속에 입을거라지만 그냥 단독으로 입는다면 딱...     2
# 1197  맨투맨같은 경우는 가성비가 좋다고 생각하는데 후리스는 좀 부직포로 만든 느낌이네요 ...     2
# 1198                         이뻐요 기본템으로 딱이에요 추천 봄코디도 좋아요     2
# 1199               순전히 로고가 다 합니다… 너무 불편해서 오래는 못 신겠어요 ㅠㅠ     2
#
# [400 rows x 2 columns]

# %% [markdown]
# ##4

# %%
four = pd.DataFrame(df1[df1['star'] ==  4])
four
# Out:
#                                                 comment  star
# 1200  입기 편하고 후드 탈부착 돼서 여러 무드 연출하기도 쉽고 좋은데 가죽냄새랑 마감이 ...     4
# 1201               색상이 예뻐서 샀어요. 얇고 시원해요. 살빼서 청바지랑 입고싶네용     4
# 1202  1. 엄청 길고 커여 ㅠㅠ 이게 xs...? 2. 사진은 안줄였고 줄일거에요 3. ...     4
# 1203  따뜻하고 모자때고 일반 패딩 처럼 입고 다닙니다 무난하게 입을 수 있는 것 같아요 ...     4
# 1204  조금 짧은 감이 있는데 괜찮은 것 같아요. 근데 좁아지는 스타일이라 움직이면서 말려...     4
# ...                                                 ...   ...
# 1595                        사이즈가 약간 크긴한데 아무옷에나 잘어울려서 좋아     4
# 1596  유럽 장기 여행 때문에 편하고 아이패드(10.5) 들어가는 크로스백이 필요해서 샀는...     4
# 1597              루즈핏으로 디자인 핏은 좋은데 털이 너무 많이 빠져서 아쉽네여 ㅜㅜ     4
# 1598                        그럭저럭 만족합니다 배송빠르고 포장상태는 좋아여~     4
# 1599  생각보다 더 옷이 오버핏하네요. 너무 어깡처럼 보여서 부담스럽긴하지만 색상 디자인은...     4
#
# [400 rows x 2 columns]

# %%
four['star'] = 3

# %%
four
# Out:
#                                                 comment  star
# 1200  입기 편하고 후드 탈부착 돼서 여러 무드 연출하기도 쉽고 좋은데 가죽냄새랑 마감이 ...     3
# 1201               색상이 예뻐서 샀어요. 얇고 시원해요. 살빼서 청바지랑 입고싶네용     3
# 1202  1. 엄청 길고 커여 ㅠㅠ 이게 xs...? 2. 사진은 안줄였고 줄일거에요 3. ...     3
# 1203  따뜻하고 모자때고 일반 패딩 처럼 입고 다닙니다 무난하게 입을 수 있는 것 같아요 ...     3
# 1204  조금 짧은 감이 있는데 괜찮은 것 같아요. 근데 좁아지는 스타일이라 움직이면서 말려...     3
# ...                                                 ...   ...
# 1595                        사이즈가 약간 크긴한데 아무옷에나 잘어울려서 좋아     3
# 1596  유럽 장기 여행 때문에 편하고 아이패드(10.5) 들어가는 크로스백이 필요해서 샀는...     3
# 1597              루즈핏으로 디자인 핏은 좋은데 털이 너무 많이 빠져서 아쉽네여 ㅜㅜ     3
# 1598                        그럭저럭 만족합니다 배송빠르고 포장상태는 좋아여~     3
# 1599  생각보다 더 옷이 오버핏하네요. 너무 어깡처럼 보여서 부담스럽긴하지만 색상 디자인은...     3
#
# [400 rows x 2 columns]

# %% [markdown]
# ##5

# %%
five = pd.DataFrame(df1[df1['star'] ==  5])
five
# Out:
#                                                 comment  star
# 1600  휘뚜루마뚜루 입고 다니기 좋습니다 로얄라이프제품들은 다 성공하는 듯!따숩고 예쁘기까...     5
# 1601                어깨 깡패됩니다 기장감이나 털 재질 전체적으로 전부 맘에 들어요     5
# 1602                   바지 짱 편합니다ㅎㅎ 색깔도 너무 마음에 들고 핏도 좋네요     5
# 1603            유니폼 브릿지 발마칸 코트! 세일.기간중 저렴하게 겟겟! 최고 말모말모     5
# 1604  무난무난 무난템입니다. 좀 무겁긴 한데 무거운만큼 따뜻한거같기도하고요. 강아지털이나...     5
# ...                                                 ...   ...
# 1995  내복입고 입으면 타이트해서 벗고 입어야 할거 같아요 허리밴딩땜에 편하고 좋네요 리얼...     5
# 1996               아이보리 치노팬츠 하나 필요해서 샀습니다. 싸게 잘 산 것 같아용     5
# 1997     사이즈 오버핏으로 넉넉하구 따뜻해서 너무 좋아요 생지랑 니트랑 같이 입으니 귀엽네요     5
# 1998  진짜 너무 이뻐요ㅠㅠ하얗고 딱 제가 원하는 색상이예요 신발이 단단하다고 해야할까요 ...     5
# 1999    너무 예쁘네요. 보풀이 잘 일어날 것 같은 느낌인데 관리 잘 해서 오래 입고 싶습니다     5
#
# [400 rows x 2 columns]

# %%
five['star'] = 4

# %%
five
# Out:
#                                                 comment  star
# 1600  휘뚜루마뚜루 입고 다니기 좋습니다 로얄라이프제품들은 다 성공하는 듯!따숩고 예쁘기까...     4
# 1601                어깨 깡패됩니다 기장감이나 털 재질 전체적으로 전부 맘에 들어요     4
# 1602                   바지 짱 편합니다ㅎㅎ 색깔도 너무 마음에 들고 핏도 좋네요     4
# 1603            유니폼 브릿지 발마칸 코트! 세일.기간중 저렴하게 겟겟! 최고 말모말모     4
# 1604  무난무난 무난템입니다. 좀 무겁긴 한데 무거운만큼 따뜻한거같기도하고요. 강아지털이나...     4
# ...                                                 ...   ...
# 1995  내복입고 입으면 타이트해서 벗고 입어야 할거 같아요 허리밴딩땜에 편하고 좋네요 리얼...     4
# 1996               아이보리 치노팬츠 하나 필요해서 샀습니다. 싸게 잘 산 것 같아용     4
# 1997     사이즈 오버핏으로 넉넉하구 따뜻해서 너무 좋아요 생지랑 니트랑 같이 입으니 귀엽네요     4
# 1998  진짜 너무 이뻐요ㅠㅠ하얗고 딱 제가 원하는 색상이예요 신발이 단단하다고 해야할까요 ...     4
# 1999    너무 예쁘네요. 보풀이 잘 일어날 것 같은 느낌인데 관리 잘 해서 오래 입고 싶습니다     4
#
# [400 rows x 2 columns]

# %% [markdown]
# ##concat

# %%
df = pd.concat([one, two, three, four, five])
df
# Out:
#                                                 comment  star
# 0     사이즈표 바꿔라 270인데 m시키고 색소침착에 딱지까지 생김 250~275 퉁치는게...     0
# 1     음 가격에 비해서 좀 많이 별로네요... 일단 목부분이 처음 왔을때부터 저렇게 쭈글...     0
# 2     주머니에 빵꾸뚫려있는데 교환환불 방법이있나요 사놓고 검수를 했어야한건지 무신사를믿고...     0
# 3            가방이 벌써 뜯어졌어요ㅠㅜ 얼마 매지도 않았는데....가방이 너무 약해요ㅠㅠ     0
# 4                      생각보다는 그저 그런 후드티였어요 그냥 일반 보세느낌이에요     0
# ...                                                 ...   ...
# 1995  내복입고 입으면 타이트해서 벗고 입어야 할거 같아요 허리밴딩땜에 편하고 좋네요 리얼...     4
# 1996               아이보리 치노팬츠 하나 필요해서 샀습니다. 싸게 잘 산 것 같아용     4
# 1997     사이즈 오버핏으로 넉넉하구 따뜻해서 너무 좋아요 생지랑 니트랑 같이 입으니 귀엽네요     4
# 1998  진짜 너무 이뻐요ㅠㅠ하얗고 딱 제가 원하는 색상이예요 신발이 단단하다고 해야할까요 ...     4
# 1999    너무 예쁘네요. 보풀이 잘 일어날 것 같은 느낌인데 관리 잘 해서 오래 입고 싶습니다     4
#
# [2000 rows x 2 columns]

# %%
# df.to_csv('total_reset_star.csv')

# %% [markdown]
# #train_test_split

# %%
dataset_train, dataset_test = train_test_split(df, test_size=0.2) # data를 train:test = 8:2 비율로 나눔

# %%
dataset_train
# Out:
#                                                 comment  star
# 463   척테일러 같은 색상 같은 사이즈 세번째 구매인데 제가 알던 척테일러가 아니에요......     1
# 1520  데일리로 정말 잘 사용하고 있습니다 컬러도 제가 원하던 진한 버건디 색상이었고 기모...     3
# 338                   그냥 베이직하우스 입으세요 딱 그거에 프린팅 박힌거에요 ㅋㅋ     0
# 1748  정말 너무 만족스럽습니다.  재질도, 핏도, 단추 디테일도, 마감까지 너무도 완벽합니다.     4
# 98       옷이 아주이뻐요 뒷판이좀이상해서그렇지   맘에들어요   적립금 기준 이상한듯 무신사     0
# ...                                                 ...   ...
# 1618  작년에 못사고 땅을 치고 후회하고 올해 샀네요. 가볍고 따뜻하고 이쁩니다. 다이와피...     4
# 1047   색이 별루에요 ㅠ ㅠ 손 잘 안 갈 것 같은 컬러.. 생얼로는 못 입을 것 같아요 ㅋㅋ     2
# 153                           너무너무너무너무너무 커요 생각한거보다 안이뻐요     0
# 1979  반스 265, 운동화 275 신는데 265 시켰는데 딱 맞는거 같아요~ 다자인이 이뻐요!     4
# 747   살쪄서 헐렁하게 입으려고 샀는데 체중이 20kg는 더 쪄보임. 옷 특성상 힙찔이처럼...     1
#
# [1600 rows x 2 columns]

# %%
# dataset_train.to_csv('reset_star_train.csv')

# %%
dataset_train.to_csv('reset_star_train.tsv', sep = '\t', index=False) # Train data를 tsv파이로 저장, 구분자 tab(\t)

# %%
dataset_test
# Out:
#                                                 comment  star
# 1122  네이비 블랙이 아니라 거의 블랙이라고 보면 될듯 모델이 입은 바지 밝기처럼 절대 안나옴.     2
# 389   신발 이쁘고 편하긴한데 배송에서 점수 다 깍아먹습니다 아무리 주문받고 제작이라지만 ...     0
# 843   핏이나 사이즈는 만족하는데 주름이 두겹으로 되어있습니다…. 기계주름을 두번한건가요?...     2
# 1320  평소 255정도 신습니다. M시키니 딱 정사이즈였습니다. 힐슬립x 발아픔x 잘 신겠...     3
# 1703         신었을때 이런 느낌입니당. 엄청 길어요. 무릎 바로 밑까지.안흘러내려 만족!     4
# ...                                                 ...   ...
# 1339                   오프화이트 감성의 카드지갑. 착한 가격에 구매하서 좋아요!     3
# 760              저렴한 ㄱㅏ격에 구매했다해도 퀄리티가 좀 실망스럽습니다 ㅠㅠ 아쉬워요     1
# 1957             폭신하고 접지력이 좋아서 평상시에 신고다니기도 좋고 러닝하기도 좋네요     4
# 1974       배송 증말로 오래 기다려받았지만 그래도 옷이 넘 예뻐서 잘입고 다니고 있습니다.     4
# 887           신발 이쁘고 발볼 부자인데도 잘 맞아요.. 다만 신고 벗을때 넘 불편하네요     2
#
# [400 rows x 2 columns]

# %%
# dataset_test.to_csv('reset_star_test.csv')

# %%
dataset_test.to_csv('reset_star_test.tsv', sep = '\t', index=False) # Test data를 tsv파이로 저장, 구분자 tab(\t)
